# %%
import json
import pandas as pd
from collections import Counter

def analyze_professor_data(json_data):
    """
    Analyze professor data to extract timetabling statistics
    
    Args:
        json_data (str): JSON string containing professor data
    
    Returns:
        dict: Dictionary containing various statistics
    """
    # Parse JSON data
    try:
        data = json.loads(json_data)
    except json.JSONDecodeError:
        print("Error: Invalid JSON data")
        return {}
    
    # Initialize statistics
    stats = {
        "total_professors": len(data),
        "total_courses": 0,
        "total_blocks": 0,
        "blocks_per_professor": {},
        "courses_per_professor": {},
        "blocks_by_campus": Counter(),
        "blocks_by_activity_type": Counter(),
        "blocks_by_level": Counter(),
        "blocks_by_parallel": Counter(),
        "avg_vacancies": 0,
        "max_vacancies": 0,
        "min_vacancies": float('inf'),
    }
    
    all_vacancies = []
    courses_set = set()  # Track unique courses
    
    # Process each professor
    for professor in data:
        rut = professor["RUT"]
        name = professor["Nombre"]
        courses = professor["Asignaturas"]
        
        # Count courses for this professor
        num_courses = len(courses)
        stats["courses_per_professor"][name] = num_courses
        stats["total_courses"] += num_courses
        
        # Calculate total blocks for this professor
        total_blocks = sum(course["Horas"] for course in courses)
        stats["blocks_per_professor"][name] = total_blocks
        stats["total_blocks"] += total_blocks
        
        # Process each course
        for course in courses:
            course_code = course["CodigoAsignatura"]
            hours = course["Horas"]
            vacancies = course["Vacantes"]
            campus = course["Campus"]
            activity = course["Actividad"]
            level = course["Nivel"]
            parallel = course["Paralelo"]
            
            # Add to unique courses set
            courses_set.add(course_code)
            
            # Update statistics
            stats["blocks_by_campus"][campus] += hours
            stats["blocks_by_activity_type"][activity] += hours
            stats["blocks_by_level"][level] += hours
            stats["blocks_by_parallel"][parallel] += hours
            
            # Track vacancies
            all_vacancies.append(vacancies)
            stats["max_vacancies"] = max(stats["max_vacancies"], vacancies)
            stats["min_vacancies"] = min(stats["min_vacancies"], vacancies)
    
    # Calculate average vacancies
    if all_vacancies:
        stats["avg_vacancies"] = sum(all_vacancies) / len(all_vacancies)
    
    # Calculate unique courses
    stats["unique_courses"] = len(courses_set)
    
    # Average blocks per professor
    if stats["total_professors"] > 0:
        stats["avg_blocks_per_professor"] = stats["total_blocks"] / stats["total_professors"]
    
    return stats

def print_statistics(stats):
    """
    Print statistics in a formatted way
    
    Args:
        stats (dict): Dictionary containing statistics
    """
    print("\n===== PROFESSOR TIMETABLE ANALYSIS =====")
    print(f"Total Professors: {stats['total_professors']}")
    print(f"Total Course Assignments: {stats['total_courses']}")
    print(f"Unique Courses: {stats['unique_courses']}")
    print(f"Total Teaching Blocks: {stats['total_blocks']}")
    print(f"Average Blocks per Professor: {stats['avg_blocks_per_professor']:.2f}")
    
    print("\n----- Blocks Per Professor -----")
    for name, blocks in stats["blocks_per_professor"].items():
        print(f"{name}: {blocks} blocks")
    
    print("\n----- Courses Per Professor -----")
    for name, courses in stats["courses_per_professor"].items():
        print(f"{name}: {courses} courses")
    
    print("\n----- Blocks by Campus -----")
    for campus, blocks in stats["blocks_by_campus"].items():
        print(f"{campus}: {blocks} blocks")
    
    print("\n----- Blocks by Activity Type -----")
    for activity, blocks in stats["blocks_by_activity_type"].items():
        print(f"{activity}: {blocks} blocks")
    
    print("\n----- Blocks by Level -----")
    for level, blocks in stats["blocks_by_level"].items():
        print(f"Level {level}: {blocks} blocks")
    
    print("\n----- Vacancies -----")
    print(f"Average Vacancies per Course: {stats['avg_vacancies']:.2f}")
    print(f"Maximum Vacancies: {stats['max_vacancies']}")
    print(f"Minimum Vacancies: {stats['min_vacancies']}")

def main():
    """
    Main function to run the analysis
    """
    # Load JSON data from file
    try:
        with open(f'full/profesores.json', 'r', encoding="utf-8") as file:
            json_data = file.read()
    except FileNotFoundError:
        print("Error: 'professors.json' file not found. Using sample data instead.")
        # If file isn't found, use the sample data string instead
        json_data = ""
    # Analyze the data
    stats = analyze_professor_data(json_data)
    
    # Print the statistics
    print_statistics(stats)
    
    # Return dataframes for further analysis if needed
    professors_df = pd.DataFrame([{
        'RUT': p['RUT'],
        'Nombre': p['Nombre'],
        'Turno': p['Turno'],
        'Num_Asignaturas': len(p['Asignaturas']),
        'Total_Horas': sum(a['Horas'] for a in p['Asignaturas'])
    } for p in json.loads(json_data)])
    
    print("\n----- Professor Dataframe -----")
    print(professors_df)
    
    # Generate timetabling summary
    print("\n===== TIMETABLING REQUIREMENTS SUMMARY =====")
    print(f"Total blocks to be scheduled: {stats['total_blocks']}")
    print(f"Number of professors needing scheduling: {stats['total_professors']}")
    print(f"Number of unique courses to schedule: {stats['unique_courses']}")
    
    # Calculate workload distribution
    blocks_list = list(stats['blocks_per_professor'].values())
    if blocks_list:
        max_blocks = max(blocks_list)
        min_blocks = min(blocks_list)
        workload_range = max_blocks - min_blocks
        print(f"Workload range: {workload_range} blocks (min: {min_blocks}, max: {max_blocks})")

if __name__ == "__main__":
    main()
# Out:
# ===== PROFESSOR TIMETABLE ANALYSIS =====
# Total Professors: 153
# Total Course Assignments: 505
# Unique Courses: 294
# Total Teaching Blocks: 2258
# Average Blocks per Professor: 14.76
#
# ----- Blocks Per Professor -----
# ROJAS RODRIGUEZ RO: 12 blocks
# PADILLA GUZMAN SIL: 26 blocks
# OBILINOVIC GONZÁLE: 14 blocks
# YÁÑEZ MUÑOZ RICARD: 14 blocks
# AZÓCAR AZÓCAR PABL: 15 blocks
# LUZA CONTRERAS JUA: 48 blocks
# VILCA ASTORGA BELF: 36 blocks
# TAPIA QUEZADA JAIM: 5 blocks
# DIAZ MIRANDA MARCO: 6 blocks
# CORTES CAMPOS EMEL: 3 blocks
# MEZA CÁRDENAS ERIK: 25 blocks
# LAM MORAGA JAIME A: 36 blocks
# WONG BARREDA EDUAR: 16 blocks
# ROJAS GONZALEZ MAR: 12 blocks
# LÓPEZ SEGUEL JULIO: 9 blocks
# URIBE PALACIOS MAR: 12 blocks
# SALAZAR PEREZ INGR: 12 blocks
# MASANA SEPULVEDA P: 12 blocks
# CARMONA MALBRAN RA: 3 blocks
# CHANDIA CONCHA HEC: 24 blocks
# CARREÑO PASTRIAN E: 11 blocks
# CONTRERAS AGUILAR: 8 blocks
# RAMÍREZ CASTILLO W: 24 blocks
# ARAYA TORRES CARLO: 12 blocks
# RANGEL MORALES JUA: 5 blocks
# SEGOVIA RIVERA JUA: 9 blocks
# VALDIVIESO VEGA CA: 11 blocks
# CASTRO CASTRO RUBÉ: 13 blocks
# AYALA ALCAZAR LUIS: 24 blocks
# VARELA VILLAGRAN J: 24 blocks
# ARAVENA APPELT HÉC: 12 blocks
# JUICA MUJICA GERAL: 12 blocks
# VALENZUELA GROLLMU: 11 blocks
# DONOSO DIAZ MARTIN: 12 blocks
# GÓMEZ BASTIDAS PED: 3 blocks
# ICARTE AHUMADA GAB: 9 blocks
# ZARZAR MAZA MIGUEL: 4 blocks
# ALBISTUR GONZALEZ: 4 blocks
# VARGAS VARGAS CRIS: 12 blocks
# ARCE RAMOS CHRISTI: 24 blocks
# OVALLE GAHONA MONI: 12 blocks
# GONZALEZ GONZALEZ: 24 blocks
# OYARZUN SILVA MAUR: 14 blocks
# TASSARA GUTIERREZ: 32 blocks
# Docente Clave Guia: 45 blocks
# RIVAS PEREZ JORGE: 36 blocks
# CORTES REYES FABIA: 12 blocks
# MOYA HENRIQUEZ HEC: 12 blocks
# PEDREROS REYES MAN: 5 blocks
# BRICEÑO ROMERO WIL: 5 blocks
# SARIAN GONZALEZ MA: 24 blocks
# LLANCA RIQUELME PA: 12 blocks
# GUZMAN BUENO JUAN: 12 blocks
# SEGUEL PALMA FREDY: 24 blocks
# MOYA SANDOVAL MARI: 24 blocks
# ETCHEVERRY MUÑOZ S: 4 blocks
# CRISÓSTOMO MARTÍNE: 24 blocks
# CRUCES CASTILLO JO: 4 blocks
# CONTRERAS ROCO GER: 4 blocks
# GALLARDO CONTRERAS: 26 blocks
# ACUÑA NAVARRO DANI: 8 blocks
# RUZ ACUÑA KARINA E: 8 blocks
# GONZALEZ GALLEGOS: 8 blocks
# ZAPATA HERNÁNDEZ C: 24 blocks
# TRONCOSO CASTRO JO: 48 blocks
# BERRIOS ZAMORA PAU: 11 blocks
# JARA MALDONADO ELI: 23 blocks
# MEZA ARRIAGADA CAT: 6 blocks
# PIZARRO GIANI EUGE: 20 blocks
# ARRIAZA SCHILLER R: 6 blocks
# PACHECO LOPEZ DANI: 12 blocks
# CARTES ARENAS FRAN: 23 blocks
# SALINAS SOLARI JAV: 8 blocks
# PICEROS FUENTES ED: 7 blocks
# MORALES RIVAS FELI: 3 blocks
# BALCARCE SANTANDER: 12 blocks
# MAMANI APALA PAOLA: 21 blocks
# GARCIA BARRERA FRA: 10 blocks
# GUERRERO JOFRE VIC: 12 blocks
# CONTRERAS ROJO CAR: 13 blocks
# SALFATTI CARVAJAL: 12 blocks
# VIVANCO GALLARDO A: 25 blocks
# LEA VALENZUELA AND: 18 blocks
# FUENTES ESPINOZA E: 11 blocks
# CEBALLOS CARTES JU: 12 blocks
# PACHECO MERCADO SE: 13 blocks
# GALLEGOS ORTIZ VIC: 12 blocks
# NAKAMINE ARAYA KIM: 8 blocks
# RODRIGUEZ ACEVEDO: 14 blocks
# VALENZUELA CORTÉS: 12 blocks
# CASTILLO TOLORZA I: 4 blocks
# RETAMALES RAMIREZ: 4 blocks
# TORRES CHÁVEZ MARC: 12 blocks
# ESPINOZA LOZANO BA: 29 blocks
# SALDAÑA PINO MANUE: 0 blocks
# PEZOA OLGUIN JAVIE: 16 blocks
# PEREIRA VASQUEZ AL: 9 blocks
# ESPINOZA TAPIA AND: 8 blocks
# GODOY ROA VÍCTOR A: 8 blocks
# HERNÁNDEZ GUZMÁN S: 8 blocks
# AHUMADA LEIVA NICO: 12 blocks
# MENARES COSSIO ELI: 5 blocks
# FREZ PARRA KEVIN B: 8 blocks
# ISLA CERDA NICOLÁS: 20 blocks
# DE LA VEGA CORNEJO: 3 blocks
# PINTO GUZMAN LUIS: 4 blocks
# SAAVEDRA SAAVEDRA: 1 blocks
# HENRIQUEZ BARTOLO: 10 blocks
# ESPINA VILLEGAS IG: 4 blocks
# VILLA CEBALLOS ISI: 1 blocks
# POBLETE PEREZ AARO: 4 blocks
# ÁVALOS ALVARADO JU: 3 blocks
# RODRÍGUEZ CLAVIJO: 3 blocks
# CALLEJAS DIAZ JUAN: 1 blocks
# VARGAS MAIRE WENDY: 22 blocks
# OSPINA GALLEGO ALE: 12 blocks
# IZQUIERDO . MARIA: 21 blocks
# FARHANG SAHLEVANI: 2 blocks
# BLANCO VINO WALTER: 60 blocks
# CESPEDES ROSSELL A: 60 blocks
# GONZALES APAZA MOI: 48 blocks
# LOIS SILVA DIEGO M: 12 blocks
# PRADO DÍAZ LUIS AL: 19 blocks
# OCHOA MEDINA HUGO: 12 blocks
# CÁREVIC RIVERA ÁLV: 3 blocks
# ALVAREZ SOTO RICAR: 12 blocks
# MUZZIO KRAUSE ALEJ: 12 blocks
# GONZÁLEZ CARVAJAL: 4 blocks
# ROJAS VALDEBENITO: 12 blocks
# SALAZAR BRIONES ER: 24 blocks
# HERRERA APABLAZA V: 15 blocks
# OYARZÚN LILLO ÁLVA: 4 blocks
# SEGURA RIVEROS DAN: 12 blocks
# AVILA SALAZAR RUFI: 48 blocks
# FRANZ GOYENECHEA N: 12 blocks
# GRAY HUIDOBRO MARÍ: 11 blocks
# DÍAZ POLANCO JOSÉ: 4 blocks
# OLIVOS ESPINOZA PE: 6 blocks
# SEPÚLVEDA LLANOS R: 24 blocks
# OLCAY BARREDA RUBE: 17 blocks
# GARCIA ARIAS REINA: 3 blocks
# ARANEDA SANCHEZ GE: 42 blocks
# LLANOS ORTIZ MARIA: 10 blocks
# JULIO EGAÑA PATRIC: 19 blocks
# ZÚÑIGA ARRIAZA RAÚ: 7 blocks
# CLARO COLLADO CORI: 27 blocks
# GANA BARRIENTOS FL: 12 blocks
# SANTANDER CORTES M: 4 blocks
# GONZALEZ NAVARRETE: 5 blocks
# CASTRO CASTRO CEFE: 20 blocks
# QUIERO GELMI ALDO: 40 blocks
# VERA CABALLERO DAN: 12 blocks
# NEIRA CORTÉS PURIS: 33 blocks
#
# ----- Courses Per Professor -----
# ROJAS RODRIGUEZ RO: 1 courses
# PADILLA GUZMAN SIL: 3 courses
# OBILINOVIC GONZÁLE: 8 courses
# YÁÑEZ MUÑOZ RICARD: 8 courses
# AZÓCAR AZÓCAR PABL: 8 courses
# LUZA CONTRERAS JUA: 4 courses
# VILCA ASTORGA BELF: 3 courses
# TAPIA QUEZADA JAIM: 2 courses
# DIAZ MIRANDA MARCO: 1 courses
# CORTES CAMPOS EMEL: 1 courses
# MEZA CÁRDENAS ERIK: 5 courses
# LAM MORAGA JAIME A: 7 courses
# WONG BARREDA EDUAR: 8 courses
# ROJAS GONZALEZ MAR: 1 courses
# LÓPEZ SEGUEL JULIO: 2 courses
# URIBE PALACIOS MAR: 1 courses
# SALAZAR PEREZ INGR: 1 courses
# MASANA SEPULVEDA P: 1 courses
# CARMONA MALBRAN RA: 2 courses
# CHANDIA CONCHA HEC: 2 courses
# CARREÑO PASTRIAN E: 5 courses
# CONTRERAS AGUILAR: 4 courses
# RAMÍREZ CASTILLO W: 2 courses
# ARAYA TORRES CARLO: 1 courses
# RANGEL MORALES JUA: 2 courses
# SEGOVIA RIVERA JUA: 5 courses
# VALDIVIESO VEGA CA: 4 courses
# CASTRO CASTRO RUBÉ: 5 courses
# AYALA ALCAZAR LUIS: 2 courses
# VARELA VILLAGRAN J: 2 courses
# ARAVENA APPELT HÉC: 1 courses
# JUICA MUJICA GERAL: 1 courses
# VALENZUELA GROLLMU: 6 courses
# DONOSO DIAZ MARTIN: 1 courses
# GÓMEZ BASTIDAS PED: 1 courses
# ICARTE AHUMADA GAB: 6 courses
# ZARZAR MAZA MIGUEL: 2 courses
# ALBISTUR GONZALEZ: 2 courses
# VARGAS VARGAS CRIS: 1 courses
# ARCE RAMOS CHRISTI: 2 courses
# OVALLE GAHONA MONI: 1 courses
# GONZALEZ GONZALEZ: 2 courses
# OYARZUN SILVA MAUR: 6 courses
# TASSARA GUTIERREZ: 5 courses
# Docente Clave Guia: 17 courses
# RIVAS PEREZ JORGE: 3 courses
# CORTES REYES FABIA: 1 courses
# MOYA HENRIQUEZ HEC: 1 courses
# PEDREROS REYES MAN: 3 courses
# BRICEÑO ROMERO WIL: 2 courses
# SARIAN GONZALEZ MA: 2 courses
# LLANCA RIQUELME PA: 1 courses
# GUZMAN BUENO JUAN: 1 courses
# SEGUEL PALMA FREDY: 2 courses
# MOYA SANDOVAL MARI: 2 courses
# ETCHEVERRY MUÑOZ S: 1 courses
# CRISÓSTOMO MARTÍNE: 2 courses
# CRUCES CASTILLO JO: 2 courses
# CONTRERAS ROCO GER: 2 courses
# GALLARDO CONTRERAS: 3 courses
# ACUÑA NAVARRO DANI: 3 courses
# RUZ ACUÑA KARINA E: 4 courses
# GONZALEZ GALLEGOS: 2 courses
# ZAPATA HERNÁNDEZ C: 2 courses
# TRONCOSO CASTRO JO: 4 courses
# BERRIOS ZAMORA PAU: 5 courses
# JARA MALDONADO ELI: 6 courses
# MEZA ARRIAGADA CAT: 4 courses
# PIZARRO GIANI EUGE: 7 courses
# ARRIAZA SCHILLER R: 4 courses
# PACHECO LOPEZ DANI: 1 courses
# CARTES ARENAS FRAN: 7 courses
# SALINAS SOLARI JAV: 2 courses
# PICEROS FUENTES ED: 3 courses
# MORALES RIVAS FELI: 1 courses
# BALCARCE SANTANDER: 1 courses
# MAMANI APALA PAOLA: 5 courses
# GARCIA BARRERA FRA: 5 courses
# GUERRERO JOFRE VIC: 1 courses
# CONTRERAS ROJO CAR: 8 courses
# SALFATTI CARVAJAL: 1 courses
# VIVANCO GALLARDO A: 6 courses
# LEA VALENZUELA AND: 2 courses
# FUENTES ESPINOZA E: 4 courses
# CEBALLOS CARTES JU: 5 courses
# PACHECO MERCADO SE: 6 courses
# GALLEGOS ORTIZ VIC: 1 courses
# NAKAMINE ARAYA KIM: 4 courses
# RODRIGUEZ ACEVEDO: 7 courses
# VALENZUELA CORTÉS: 6 courses
# CASTILLO TOLORZA I: 2 courses
# RETAMALES RAMIREZ: 2 courses
# TORRES CHÁVEZ MARC: 1 courses
# ESPINOZA LOZANO BA: 11 courses
# SALDAÑA PINO MANUE: 1 courses
# PEZOA OLGUIN JAVIE: 6 courses
# PEREIRA VASQUEZ AL: 3 courses
# ESPINOZA TAPIA AND: 4 courses
# GODOY ROA VÍCTOR A: 4 courses
# HERNÁNDEZ GUZMÁN S: 4 courses
# AHUMADA LEIVA NICO: 1 courses
# MENARES COSSIO ELI: 3 courses
# FREZ PARRA KEVIN B: 6 courses
# ISLA CERDA NICOLÁS: 10 courses
# DE LA VEGA CORNEJO: 2 courses
# PINTO GUZMAN LUIS: 2 courses
# SAAVEDRA SAAVEDRA: 1 courses
# HENRIQUEZ BARTOLO: 4 courses
# ESPINA VILLEGAS IG: 4 courses
# VILLA CEBALLOS ISI: 1 courses
# POBLETE PEREZ AARO: 2 courses
# ÁVALOS ALVARADO JU: 1 courses
# RODRÍGUEZ CLAVIJO: 1 courses
# CALLEJAS DIAZ JUAN: 1 courses
# VARGAS MAIRE WENDY: 8 courses
# OSPINA GALLEGO ALE: 1 courses
# IZQUIERDO . MARIA: 6 courses
# FARHANG SAHLEVANI: 2 courses
# BLANCO VINO WALTER: 5 courses
# CESPEDES ROSSELL A: 5 courses
# GONZALES APAZA MOI: 4 courses
# LOIS SILVA DIEGO M: 1 courses
# PRADO DÍAZ LUIS AL: 8 courses
# OCHOA MEDINA HUGO: 1 courses
# CÁREVIC RIVERA ÁLV: 2 courses
# ALVAREZ SOTO RICAR: 1 courses
# MUZZIO KRAUSE ALEJ: 1 courses
# GONZÁLEZ CARVAJAL: 2 courses
# ROJAS VALDEBENITO: 1 courses
# SALAZAR BRIONES ER: 2 courses
# HERRERA APABLAZA V: 2 courses
# OYARZÚN LILLO ÁLVA: 2 courses
# SEGURA RIVEROS DAN: 1 courses
# AVILA SALAZAR RUFI: 4 courses
# FRANZ GOYENECHEA N: 1 courses
# GRAY HUIDOBRO MARÍ: 6 courses
# DÍAZ POLANCO JOSÉ: 1 courses
# OLIVOS ESPINOZA PE: 1 courses
# SEPÚLVEDA LLANOS R: 2 courses
# OLCAY BARREDA RUBE: 6 courses
# GARCIA ARIAS REINA: 1 courses
# ARANEDA SANCHEZ GE: 4 courses
# LLANOS ORTIZ MARIA: 5 courses
# JULIO EGAÑA PATRIC: 8 courses
# ZÚÑIGA ARRIAZA RAÚ: 3 courses
# CLARO COLLADO CORI: 7 courses
# GANA BARRIENTOS FL: 1 courses
# SANTANDER CORTES M: 2 courses
# GONZALEZ NAVARRETE: 2 courses
# CASTRO CASTRO CEFE: 5 courses
# QUIERO GELMI ALDO: 7 courses
# VERA CABALLERO DAN: 1 courses
# NEIRA CORTÉS PURIS: 6 courses
#
# ----- Blocks by Campus -----
# Playa Brava: 2258 blocks
#
# ----- Blocks by Activity Type -----
# Teo: 1553 blocks
# Lab: 348 blocks
# Pra: 50 blocks
# Tal: 213 blocks
# Ayu: 79 blocks
# Tut: 15 blocks
#
# ----- Blocks by Level -----
# Level 8: 452 blocks
# Level 7: 92 blocks
# Level 9: 135 blocks
# Level 2: 87 blocks
# Level 3: 52 blocks
# Level 4: 159 blocks
# Level 6: 557 blocks
# Level 5: 293 blocks
# Level 10: 381 blocks
# Level 1: 50 blocks
#
# ----- Vacancies -----
# Average Vacancies per Course: 30.59
# Maximum Vacancies: 65
# Minimum Vacancies: 1
#
# ----- Professor Dataframe -----
#             RUT              Nombre  Turno  Num_Asignaturas  Total_Horas
# 0    10087939-5  ROJAS RODRIGUEZ RO      0                1           12
# 1    10090332-6  PADILLA GUZMAN SIL      1                3           26
# 2    10254482-K  OBILINOVIC GONZÁLE      2                8           14
# 3    10279921-6  YÁÑEZ MUÑOZ RICARD      3                8           14
# 4    10316944-5  AZÓCAR AZÓCAR PABL      4                8           15
# ..          ...                 ...    ...              ...          ...
# 148   9803832-9  GONZALEZ NAVARRETE    148                2            5
# 149   9813404-2  CASTRO CASTRO CEFE    149                5           20
# 150   9816456-1   QUIERO GELMI ALDO    150                7           40
# 151   9866237-5  VERA CABALLERO DAN    151                1           12
# 152   9996891-5  NEIRA CORTÉS PURIS    152                6           33
#
# [153 rows x 5 columns]
#
# ===== TIMETABLING REQUIREMENTS SUMMARY =====
# Total blocks to be scheduled: 2258
# Number of professors needing scheduling: 153
# Number of unique courses to schedule: 294
# Workload range: 60 blocks (min: 0, max: 60)

# %%
# %pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
